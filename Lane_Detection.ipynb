# %%
# !pip install gitpython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import git

repo_url = "https://github.com/Manoah1401/Road-Segmentation-Dataset"
destination_folder = "sample"

git.Repo.clone_from(repo_url, destination_folder)
# Out:
# <git.repo.base.Repo '/content/sample/.git'>

# %%
import os
import matplotlib.pyplot as plt
import matplotlib. image as mpimg
import random
def view_random_image(target_dir,target_class):
  target_folder=target_dir+target_class

  random_image1=random.sample(os.listdir(target_folder),1)
  print(random_image1)

  img=mpimg.imread(target_folder+'/'+random_image1[0])
  plt.imshow(img)

  return img

# %%
img=view_random_image("sample/train/","image")
# Out:
# ['024541_leftImg8bit.png']
